# %% [markdown]
# # Connect To MySql

# %%
# With MySql Python Connector

# %%
import mysql.connector

conn_db = mysql.connector.connect(user='root', password='udin',
                              host='127.0.0.1',
                              database='cmn')
print(conn_db)

# %% [markdown]
# # Select Table

# %%
import mysql.connector
import pandas as nda

conn_db = mysql.connector.connect(user='root', password='udin',
                              host='127.0.0.1',
                              database='cmn')
sql_user = "select * from m_user"
show_data_user = nda.read_sql_query(sql_user, conn_db)
show_data_user
# Out:
#        user_id      surname  \
# 0    US-000001          hei
# 1    US-000002         hei2
# 2    US-000003         hei3
# 3    US-000004         hei4
# 4    US-000005         hei5
# 5    US-000006         hei6
# 6    US-000007         hei7
# 7    US-000008         hei8
# 8    US-000009         hei9
# 9    US-000010        hei10
# 10   US-000011        hei11
# 11   US-000012        hei12
# 12   US-000013        hei13
# 13   US-000014        hei14
# 14   US-000015        hei15
# 15   US-000016        hei16
# 16   US-000017        hei17
# 17   US-000018        hei18
# 18   US-000019        hei19
# 19   US-000020        hei20
# 20   US-000021        hei21
# 21   US-000022        hei22
# 22   US-000023        hei23
# 23   US-000024        hei24
# 24   US-000025        hei25
# 25   US-000026        hei26
# 26   US-000027        hei27
# 27   US-000028        hei28
# 28   US-000029        hei29
# 29   US-000030        hei30
# ..         ...          ...
# 207  US-000208       minnie
# ...

# %% [markdown]
# # Select Column

# %%
# Select One Column

# %%
import mysql.connector
import pandas as nda

conn_db = mysql.connector.connect(user='root', password='udin',
                              host='127.0.0.1',
                              database='cmn')
sql_user = "select * from m_user"
show_data_user = nda.read_sql_query(sql_user, conn_db)
show_data_user[['surname',]]
# Out:
#          surname
# 0            hei
# 1           hei2
# 2           hei3
# 3           hei4
# 4           hei5
# 5           hei6
# 6           hei7
# 7           hei8
# 8           hei9
# 9          hei10
# 10         hei11
# 11         hei12
# 12         hei13
# 13         hei14
# 14         hei15
# 15         hei16
# 16         hei17
# 17         hei18
# 18         hei19
# 19         hei20
# 20         hei21
# 21         hei22
# 22         hei23
# 23         hei24
# 24         hei25
# 25         hei26
# 26         hei27
# 27         hei28
# 28         hei29
# 29         hei30
# ..           ...
# 207       minnie
# 208       donald
# 209       muzuka
# 210       sizuka
# 211      doremon
# 212       nobita
# 213          tom
# 214        jerry
# 215        suneo
# 216         joko
# 217        giant
# 218       basuki
# 219       tjahya
# 220          uzy
# 221        andre
# 222       jeffry
# 223          ham
# 224        ahmad
# 225         teri
# 226         yudi
# ...

# %%
# Select Multiple Column

# %%
import mysql.connector
import pandas as nda

conn_db = mysql.connector.connect(user='root', password='udin',
                              host='127.0.0.1',
                              database='cmn')
sql_user = "select * from m_user"
show_data_user = nda.read_sql_query(sql_user, conn_db)
show_data_user[['user_id','surname']]
# Out:
#        user_id      surname
# 0    US-000001          hei
# 1    US-000002         hei2
# 2    US-000003         hei3
# 3    US-000004         hei4
# 4    US-000005         hei5
# 5    US-000006         hei6
# 6    US-000007         hei7
# 7    US-000008         hei8
# 8    US-000009         hei9
# 9    US-000010        hei10
# 10   US-000011        hei11
# 11   US-000012        hei12
# 12   US-000013        hei13
# 13   US-000014        hei14
# 14   US-000015        hei15
# 15   US-000016        hei16
# 16   US-000017        hei17
# 17   US-000018        hei18
# 18   US-000019        hei19
# 19   US-000020        hei20
# 20   US-000021        hei21
# 21   US-000022        hei22
# 22   US-000023        hei23
# 23   US-000024        hei24
# 24   US-000025        hei25
# 25   US-000026        hei26
# 26   US-000027        hei27
# 27   US-000028        hei28
# 28   US-000029        hei29
# 29   US-000030        hei30
# ..         ...          ...
# 207  US-000208       minnie
# ...
